# %% [markdown]
# <a href="https://colab.research.google.com/github/reglamarcador115/labo2025v/blob/main/src/rpart/102_FinalTrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Arbol elemental con libreria  rpart

# %% [markdown]
# ## Introduccion

# %% [markdown]
# Este es el primer notebook/script de la materia Laboratorio de Implementacion I, se expone en la primera clase.
# <br>Se utilizan Arboles de Decision, librería **rpart**,  el primer algoritmo, el más simple que utilizaremos en la materia pero que es el fundamento de los Ensembles de Arboles de Decision tales como  Random Forest y  Gradient Boosting of Decision Trees (XGBoost/LightGBM)
# <br>La materia posee un dataset con 31 meses, en las primeras clases toda la cohorte, independiente de la modalidad elegida, utilizará **dataset_pequeno** que posee apenas un mes histórico 202107 y obviamente el mes donde se debe realizar la predicción 202109
# <br>Este primer notebook/script **no** desarrolla todas las etapas necesarias para la generación de un buen modelo, apenas posee la parte final del pipeline/workflow.

# %% [markdown]
# ### Limitaciones

# %% [markdown]
# Este primer y elemental notebook/script supone estas simplificaciónes:
# * Solo se dispone del mes 202107 con el campo clase_ternaria completo, es el unico mes donde entrenar
# * Se decidió previamente, de alguna forma, que la etapa de Final Training se hará sobre TODO el dataset de 202107
# * Se obtuvieron previamente los hiperparámetros optimos de la libería **rpart** para este problema, mediante algun tipo de busqueda búsqueda.  Esta es la etapa que demandará decenas de horas para quienes opten por la *modalidad Analista Senior*
# * No se realiza ningun tipo de feature engineering intra-mes
# * Al no disponer de datos históricos no se realiza ningun tipo de feature engineering histórico
# * No hay ningun analisis de la calidad de los campos, no se analiza si ocurrió alguna catástrofe ese mes y algun campo no se calculó correctamente
# * Noy hay ningun tipo de análisis de Data Drifting entre los meses de 202107 y 202109
# * Obedientemente se trabaja utlizando como clase el campo **clase_ternaria** sin ningun tipo de transformacion
#
#
# <br> Obviamente, a lo largo de la materia se avanzará sobre todas las limitacinoes anteriores.

# %% [markdown]
# ## Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ## Final Train y generacion de la prediccion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  657219 35.1 1454477    77.7 1326046  70.9
# Vcells 1220161  9.4 8388608    64.0 1975136  15.1

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table**  **rpart** y  **rpart.plot**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
if (!require("rpart.plot")) install.packages("rpart.plot")
require("rpart.plot")
# Out:
# Loading required package: data.table
#
# Loading required package: rpart
#
# Loading required package: rpart.plot
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rpart.plot’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: rpart.plot

# %% [markdown]
# Crear y moverse a la carpeta donde se va a trabajar

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "KA2001"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# ## Final Training

# %% [markdown]
# ### Final Train Dataset

# %% [markdown]
# Es importante notar que para el entrenamiento final utilizo el mes de 202107 completo sin ningun tipo particion  train/test, aqui no hay random, aqui no hay semillas

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")
dtrain_final <- dataset[foto_mes == 202107] # defino donde voy a entrenar

# %% [markdown]
# ### Hyperparameters

# %% [markdown]
# Aqui los hiperparámetros estan hardcodeados
# <br> Usted puede jugar con ellos manualmente
# <br> En las siguientes clases veremos como encontrar previamente los hiperparámetros óptimos, para ser copiados aquí

# %%
param_final <- list (
  "cp"= -1, # complejidad minima
  "minsplit"= 250, # minima cantidad de regs en un nodo para hacer el split
  "minbucket"= 100, # minima cantidad de regs en una hoja
  "maxdepth"= 3 # profundidad máxima del arbol
)

# %% [markdown]
# ### Training

# %%
# genero el modelo,  aqui se construye el arbol
# quiero predecir clase_ternaria a partir de el resto de las variables
modelo_final <- rpart(
    formula= "clase_ternaria ~ .",
    data= dtrain_final, # los datos donde voy a entrenar
    xval= 0,
    control= param_final
)

# %% [markdown]
# #### Impresion del modelo

# %%
# grafico el arbol
options(repr.plot.width=30, repr.plot.height=20 )

prp(modelo_final,
    extra= 101,
    digits= -5,
    branch= 1,
    type= 4,
    varlen= 0,
    faclen= 0
)
# Out:
# plot without title

# %% [markdown]
# ## Dataset Future

# %% [markdown]
# Aqui se define el dataset donde quiero hacer la prediccion final, generalmente esto viene dado por el problema y es trivial su eleccion

# %%
dfuture <- dataset[foto_mes == 202109] # defino donde voy a aplicar el modelo

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo_final a los datos del futuro

# %%
# aplico el modelo a los datos nuevos
prediccion <- predict(
    object= modelo_final,
    newdata= dfuture,
    type= "prob"
)

# veo que  quedó en predccion
# es una matriz, una linea por registro del dataset dfuture
# una columna para cada uno de los valores de la clase
prediccion
# Out:
#        BAJA+1      BAJA+2      CONTINUA
# 1      0.002127452 0.002950532 0.994922
# 2      0.002127452 0.002950532 0.994922
# 3      0.044801838 0.043270151 0.911928
# 4      0.002127452 0.002950532 0.994922
# 5      0.002127452 0.002950532 0.994922
# 6      0.002127452 0.002950532 0.994922
# 7      0.002127452 0.002950532 0.994922
# 8      0.002127452 0.002950532 0.994922
# 9      0.002127452 0.002950532 0.994922
# 10     0.002127452 0.002950532 0.994922
# 11     0.002127452 0.002950532 0.994922
# 12     0.002127452 0.002950532 0.994922
# 13     0.002127452 0.002950532 0.994922
# 14     0.002127452 0.002950532 0.994922
# 15     0.002127452 0.002950532 0.994922
# 16     0.002127452 0.002950532 0.994922
# 17     0.002127452 0.002950532 0.994922
# 18     0.002127452 0.002950532 0.994922
# 19     0.002127452 0.002950532 0.994922
# 20     0.002127452 0.002950532 0.994922
# 21     0.002127452 0.002950532 0.994922
# 22     0.002127452 0.002950532 0.994922
# 23     0.002127452 0.002950532 0.994922
# 24     0.002127452 0.002950532 0.994922
# 25     0.002127452 0.002950532 0.994922
# 26     0.002127452 0.002950532 0.994922
# 27     0.002127452 0.002950532 0.994922
# 28     0.002127452 0.002950532 0.994922
# 29     0.002127452 0.002950532 0.994922
# 30     0.002127452 0.002950532 0.994922
# ⋮      ⋮           ⋮           ⋮
# 165064 0.025481869 0.025155178 0.9493630
# 165065 0.025481869 0.025155178 0.9493630
# 165066 0.025481869 0.025155178 0.9493630
# 165067 0.025481869 0.025155178 0.9493630
# 165068 0.025481869 0.025155178 0.9493630
# 165069 0.025481869 0.025155178 0.9493630
# 165070 0.025481869 0.025155178 0.9493630
# 165071 0.012203732 0.013514876 0.9742814
# 165072 0.025481869 0.025155178 0.9493630
# 165073 0.025481869 0.025155178 0.9493630
# 165074 0.025481869 0.025155178 0.9493630
# 165075 0.025481869 0.025155178 0.9493630
# 165076 0.118529632 0.133908477 0.7475619
# 165077 0.044801838 0.043270151 0.9119280
# 165078 0.025481869 0.025155178 0.9493630
# 165079 0.025481869 0.025155178 0.9493630
# 165080 0.025481869 0.025155178 0.9493630
# 165081 0.025481869 0.025155178 0.9493630
# 165082 0.025481869 0.025155178 0.9493630
# 165083 0.025481869 0.025155178 0.9493630
# 165084 0.002127452 0.002950532 0.9949220
# 165085 0.025481869 0.025155178 0.9493630
# 165086 0.025481869 0.025155178 0.9493630
# 165087 0.025481869 0.025155178 0.9493630
# 165088 0.025481869 0.025155178 0.9493630
# 165089 0.012203732 0.013514876 0.9742814
# 165090 0.012203732 0.013514876 0.9742814
# 165091 0.025481869 0.025155178 0.9493630
# 165092 0.025481869 0.025155178 0.9493630
# 165093 0.025481869 0.025155178 0.9493630

# %% [markdown]
# ## Tabla Prediccion

# %%
tb_prediccion <- as.data.table(list(
  "numero_de_cliente" = dfuture$numero_de_cliente,
  "prob"=prediccion[, "BAJA+2"]
))

# %% [markdown]
# ## Decision

# %%
# decido a quien se envia estimulo y a quien no
# como trabajo con clase_ternaria puedo hacer el corte en 1/40
# solo le envio estimulo a los registros
#  con probabilidad de BAJA+2 mayor  a  1/40

tb_prediccion[, Predicted := prob > (1/40) ]

# veo que hay en tb_prediccion
tb_prediccion
# Out:
#        numero_de_cliente prob        Predicted
# 1      29183733          0.002950532 FALSE
# 2      29184468          0.002950532 FALSE
# 3      29185245          0.043270151  TRUE
# 4      29186441          0.002950532 FALSE
# 5      29186475          0.002950532 FALSE
# 6      29187730          0.002950532 FALSE
# 7      29187764          0.002950532 FALSE
# 8      29187961          0.002950532 FALSE
# 9      29189899          0.002950532 FALSE
# 10     29189993          0.002950532 FALSE
# 11     29190113          0.002950532 FALSE
# 12     29192179          0.002950532 FALSE
# 13     29193101          0.002950532 FALSE
# 14     29193281          0.002950532 FALSE
# 15     29193324          0.002950532 FALSE
# 16     29195356          0.002950532 FALSE
# 17     29195433          0.002950532 FALSE
# 18     29196099          0.002950532 FALSE
# 19     29196902          0.002950532 FALSE
# 20     29198055          0.002950532 FALSE
# 21     29198891          0.002950532 FALSE
# 22     29199242          0.002950532 FALSE
# 23     29200335          0.002950532 FALSE
# 24     29200343          0.002950532 FALSE
# 25     29200514          0.002950532 FALSE
# 26     29200651          0.002950532 FALSE
# 27     29200727          0.002950532 FALSE
# 28     29200770          0.002950532 FALSE
# 29     29200984          0.002950532 FALSE
# 30     29201086          0.002950532 FALSE
# ⋮      ⋮                 ⋮           ⋮
# 165064 187967614         0.025155178  TRUE
# 165065 187969270         0.025155178  TRUE
# 165066 187989740         0.025155178  TRUE
# 165067 187999433         0.025155178  TRUE
# 165068 188009390         0.025155178  TRUE
# 165069 188009578         0.025155178  TRUE
# 165070 188015094         0.025155178  TRUE
# 165071 188017716         0.013514876 FALSE
# 165072 188019279         0.025155178  TRUE
# 165073 188031482         0.025155178  TRUE
# 165074 188042080         0.025155178  TRUE
# 165075 188054394         0.025155178  TRUE
# 165076 188055368         0.133908477  TRUE
# 165077 188057878         0.043270151  TRUE
# 165078 188061679         0.025155178  TRUE
# 165079 188062558         0.025155178  TRUE
# 165080 188064497         0.025155178  TRUE
# 165081 188071815         0.025155178  TRUE
# 165082 188073113         0.025155178  TRUE
# 165083 188074787         0.025155178  TRUE
# 165084 188084847         0.002950532 FALSE
# 165085 188096188         0.025155178  TRUE
# 165086 188097537         0.025155178  TRUE
# 165087 188100654         0.025155178  TRUE
# 165088 188101739         0.025155178  TRUE
# 165089 188115120         0.013514876 FALSE
# 165090 188116871         0.013514876 FALSE
# 165091 188122277         0.025155178  TRUE
# 165092 188128903         0.025155178  TRUE
# 165093 188136205         0.025155178  TRUE

# %% [markdown]
# ## Kaggle

# %%
# genero el archivo para Kaggle
# en el formato requerido por Kaggle
# <numero_de_cliente, Predicted>  separados por coma, estension .csv

archivo_kaggle <- "K101_001.csv"

fwrite( tb_prediccion[, list(numero_de_cliente, Predicted)],
    file = archivo_kaggle,
    sep = ","
)

# %% [markdown]
# ### Kaggle Competition Submit

# %% [markdown]
# Google Colab ya trae instalada una libreria llamada **kaggle** de python, que permite hacer submits a la Plataforma Kaggle

# %%
comando <- "kaggle competitions submit"
competencia <- "-c labo-i-2025-virtual-analista-sr"
arch <- paste( "-f", archivo_kaggle)

# %%
mensaje <-  paste0( "-m 'cp=", param_final$cp, "  minsplit=", param_final$minsplit, "  minbucket=", param_final$minbucket, "  maxdepth=", param_final$maxdepth, "'")

# %%
linea <- paste( comando, competencia, arch, mensaje)

# este el el comando que correria desde el prompt de Linux
linea
# Out:
# [1] "kaggle competitions submit -c labo-i-2025-virtual-analista-sr -f K101_001.csv -m 'cp=-1  minsplit=250  minbucket=100  maxdepth=3'"

# %%
# ejecuto el comando
salida <- system(linea, intern=TRUE)
cat(salida)
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr

# %% [markdown]
# ## Tarea para el Hogar

# %% [markdown]
# Explorar manualmente que hiperparámetros genera una mayor ganancia en Kaggle
# <br> Si en un momento logra quedar en primera posición del Private Leaderboard, saquese una selfie
